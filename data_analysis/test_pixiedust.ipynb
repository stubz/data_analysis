# %% [markdown]
# https://qiita.com/pocket_kyoto/items/8d1fbcbca5d5dfd1dbd5#python%E3%81%A7%E7%88%86%E9%80%9F%E3%81%A7%E3%83%87%E3%83%BC%E3%82%BF%E9%9B%86%E8%A8%88%E3%81%99%E3%82%8B%E6%96%B9%E6%B3%95%E4%BD%93%E6%84%9F%E6%89%80%E8%A6%81%E6%99%82%E9%96%935%E5%88%86

# %%
import pandas as pd
import pandas_profiling as pp
import pixiedust as px

from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# df = pd.read_csv('hoge.csv')
pp.ProfileReport(df)
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.17</span>
#         </div>
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
# ...

# %%
px.display(df)
# Out:
# <script>
#     //Marker 8ea00388
#     setTimeout(function(){
#         var cells=IPython.notebook.get_cells().filter(function(cell){
#             if(!cell.output_area || !cell.output_area.outputs){
#                 return false;
#             }
#             return cell.output_area.outputs.filter(function(output){
#                 if (output.output_type==="display_data"&&output.data&&output.data["text/html"]){
#                     return output.data["text/html"].includes("//Marker 8ea00388")
#                 }
#                 return false;
#             }).length > 0;
#         });
#         if(cells.length>0){
#             var cell=cells[0];
#             var cellId=cell.cell_id;
#             var cellMetadata=cell._metadata.pixiedust;
#             var old_msg_id = cell.last_msg_id;
#             if (old_msg_id) {
#                 cell.kernel.clear_callbacks_for_msg(old_msg_id);
#             }
#             function getCellWidth(){
#                 try{
# ...

# %%
px.sampleData()
# Out:
# <table class="table table-hover pd_save" style="font-size:small">
#   <thead>
#     <tr>
#       <th align="center" valign="middle">Id</th>
#       <th>Name</th>
#       <th>Topic</th>
#       <th>Publisher</th>
#     </tr>
#   </thead>
#   <tbody>
#
#
#     <tr>
#         <td>1</td>
#         <td>Car performance data</td>
#         <td>Transportation</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>2</td>
#         <td>Sample retail sales transactions, January 2009</td>
#         <td>Economy & Business</td>
#         <td>IBM Cloud Data Services</td>
#     </tr>
#
#
#
#     <tr>
#         <td>3</td>
#         <td>Total population by country</td>
#         <td>Society</td>
#         <td>IBM Cloud Data Services</td>
#     </tr>
#
#
#
#     <tr>
#         <td>4</td>
#         <td>GoSales Transactions for Naive Bayes Model</td>
#         <td>Leisure</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>5</td>
# ...

# %%
home_df = px.sampleData(6)
# Out:
# ...
# Downloaded 999888 bytes
# Creating pandas DataFrame for 'Million dollar home sales in Massachusetts, USA Feb 2017 through Jan 2018'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'Million dollar home sales in Massachusetts, USA Feb 2017 through Jan 2018'

# %%
from IPython.display import display, HTML
px.display(home_df)
# Out:
# <script>
#     //Marker f49dfda9
#     setTimeout(function(){
#         var cells=IPython.notebook.get_cells().filter(function(cell){
#             if(!cell.output_area || !cell.output_area.outputs){
#                 return false;
#             }
#             return cell.output_area.outputs.filter(function(output){
#                 if (output.output_type==="display_data"&&output.data&&output.data["text/html"]){
#                     return output.data["text/html"].includes("//Marker f49dfda9")
#                 }
#                 return false;
#             }).length > 0;
#         });
#         if(cells.length>0){
#             var cell=cells[0];
#             var cellId=cell.cell_id;
#             var cellMetadata=cell._metadata.pixiedust;
#             var old_msg_id = cell.last_msg_id;
#             if (old_msg_id) {
#                 cell.kernel.clear_callbacks_for_msg(old_msg_id);
#             }
#             function getCellWidth(){
#                 try{
# ...
